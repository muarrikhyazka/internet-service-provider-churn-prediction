# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
# !pip install dython --user
from dython.nominal import associations, identify_nominal_columns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, roc_auc_score, RocCurveDisplay, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
# !pip install catboost
from catboost import CatBoostClassifier
# !pip install imbalanced-learn
# !pip install imblearn
# from imblearn.over_sampling import SMOTE
# from hyperopt import STATUS_OK, Trials, fmin, hp, tpe
# !pip install optuna
import optuna
pd.options.display.max_columns=None
# Out:
# Requirement already satisfied: dython in c:\users\muarrikh yazka\appdata\roaming\python\python38\site-packages (0.7.3)
# Requirement already satisfied: scipy>=1.7.1 in c:\users\muarrikh yazka\appdata\roaming\python\python38\site-packages (from dython) (1.10.1)
# Requirement already satisfied: scikit-learn>=0.24.2 in c:\users\muarrikh yazka\appdata\roaming\python\python38\site-packages (from dython) (1.2.1)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from dython) (1.24.2)
# Requirement already satisfied: matplotlib>=3.5.3 in c:\users\muarrikh yazka\appdata\roaming\python\python38\site-packages (from dython) (3.7.0)
# Requirement already satisfied: scikit-plot>=0.3.7 in c:\users\muarrikh yazka\appdata\roaming\python\python38\site-packages (from dython) (0.3.7)
# Requirement already satisfied: psutil>=5.9.1 in c:\users\muarrikh yazka\appdata\roaming\python\python38\site-packages (from dython) (5.9.4)
# Requirement already satisfied: seaborn>=0.12.0 in c:\users\muarrikh yazka\appdata\roaming\python\python38\site-packages (from dython) (0.12.2)
# Requirement already satisfied: pandas>=1.4.2 in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from dython) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from matplotlib>=3.5.3->dython) (2.8.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from matplotlib>=3.5.3->dython) (8.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from matplotlib>=3.5.3->dython) (2.4.7)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\muarrikh yazka\appdata\roaming\python\python38\site-packages (from matplotlib>=3.5.3->dython) (4.38.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\muarrikh yazka\appdata\roaming\python\python38\site-packages (from matplotlib>=3.5.3->dython) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from matplotlib>=3.5.3->dython) (0.10.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from matplotlib>=3.5.3->dython) (21.3)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from matplotlib>=3.5.3->dython) (5.10.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from matplotlib>=3.5.3->dython) (1.3.1)
# Requirement already satisfied: six in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib>=3.5.3->dython) (1.15.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from importlib-resources>=3.2.0->matplotlib>=3.5.3->dython) (3.4.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from pandas>=1.4.2->dython) (2022.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from scikit-learn>=0.24.2->dython) (2.1.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\muarrikh yazka\appdata\roaming\python\python38\site-packages (from scikit-learn>=0.24.2->dython) (1.2.0)
# Requirement already satisfied: catboost in c:\users\muarrikh yazka\anaconda3\lib\site-packages (0.26.1)
# Requirement already satisfied: six in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from catboost) (1.15.0)
# Requirement already satisfied: graphviz in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from catboost) (0.17)
# Requirement already satisfied: plotly in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from catboost) (5.2.1)
# Requirement already satisfied: scipy in c:\users\muarrikh yazka\appdata\roaming\python\python38\site-packages (from catboost) (1.10.1)
# Requirement already satisfied: matplotlib in c:\users\muarrikh yazka\appdata\roaming\python\python38\site-packages (from catboost) (3.7.0)
# Requirement already satisfied: pandas>=0.24.0 in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from catboost) (1.5.3)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from catboost) (1.24.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from pandas>=0.24.0->catboost) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from pandas>=0.24.0->catboost) (2.8.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\muarrikh yazka\appdata\roaming\python\python38\site-packages (from matplotlib->catboost) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from matplotlib->catboost) (0.10.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from matplotlib->catboost) (21.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\muarrikh yazka\appdata\roaming\python\python38\site-packages (from matplotlib->catboost) (1.0.7)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from matplotlib->catboost) (2.4.7)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from matplotlib->catboost) (5.10.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from matplotlib->catboost) (8.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->catboost) (3.4.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from plotly->catboost) (8.0.1)
# Requirement already satisfied: imbalanced-learn in c:\users\muarrikh yazka\anaconda3\lib\site-packages (0.8.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\muarrikh yazka\appdata\roaming\python\python38\site-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from imbalanced-learn) (1.24.2)
# Requirement already satisfied: scikit-learn>=0.24 in c:\users\muarrikh yazka\appdata\roaming\python\python38\site-packages (from imbalanced-learn) (1.2.1)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\muarrikh yazka\appdata\roaming\python\python38\site-packages (from imbalanced-learn) (1.10.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from scikit-learn>=0.24->imbalanced-learn) (2.1.0)
# Requirement already satisfied: imblearn in c:\users\muarrikh yazka\anaconda3\lib\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from imblearn) (0.8.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\muarrikh yazka\appdata\roaming\python\python38\site-packages (from imbalanced-learn->imblearn) (1.2.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.24.2)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\muarrikh yazka\appdata\roaming\python\python38\site-packages (from imbalanced-learn->imblearn) (1.10.1)
# Requirement already satisfied: scikit-learn>=0.24 in c:\users\muarrikh yazka\appdata\roaming\python\python38\site-packages (from imbalanced-learn->imblearn) (1.2.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from scikit-learn>=0.24->imbalanced-learn->imblearn) (2.1.0)
# Collecting optuna
#   Downloading optuna-3.1.0-py3-none-any.whl (365 kB)
# Collecting colorlog
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Collecting cmaes>=0.9.1
#   Downloading cmaes-0.9.1-py3-none-any.whl (21 kB)
# Requirement already satisfied: PyYAML in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from optuna) (5.4.1)
# Requirement already satisfied: numpy in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from optuna) (1.24.2)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from optuna) (1.9.2)
# Requirement already satisfied: sqlalchemy>=1.3.0 in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from optuna) (1.4.7)
# Requirement already satisfied: tqdm in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from optuna) (4.59.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from optuna) (21.3)
# Requirement already satisfied: Mako in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from alembic>=1.5.0->optuna) (1.2.4)
# Requirement already satisfied: importlib-metadata in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from alembic>=1.5.0->optuna) (3.10.0)
# Requirement already satisfied: importlib-resources in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from alembic>=1.5.0->optuna) (5.10.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from packaging>=20.0->optuna) (2.4.7)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from sqlalchemy>=1.3.0->optuna) (1.0.0)
# Requirement already satisfied: colorama in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from colorlog->optuna) (0.4.4)
# Requirement already satisfied: zipp>=0.5 in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from importlib-metadata->alembic>=1.5.0->optuna) (3.4.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\muarrikh yazka\anaconda3\lib\site-packages (from Mako->alembic>=1.5.0->optuna) (2.0.1)
# Installing collected packages: colorlog, cmaes, optuna
# Successfully installed cmaes-0.9.1 colorlog-6.7.0 optuna-3.1.0

# %%
df_raw = pd.read_csv('data/internet_service_churn.csv')

# %%
df = df_raw.copy()

# %%
df.head()
# Out:
#    id  is_tv_subscriber  is_movie_package_subscriber  subscription_age  \
# 0  15                 1                            0             11.95
# 1  18                 0                            0              8.22
# 2  23                 1                            0              8.91
# 3  27                 0                            0              6.87
# 4  34                 0                            0              6.39
#
#    bill_avg  reamining_contract  service_failure_count  download_avg  \
# 0        25                0.14                      0           8.4
# 1         0                 NaN                      0           0.0
# 2        16                0.00                      0          13.7
# 3        21                 NaN                      1           0.0
# 4         0                 NaN                      0           0.0
#
#    upload_avg  download_over_limit  churn
# 0         2.3                    0      0
# 1         0.0                    0      1
# 2         0.9                    0      1
# 3         0.0                    0      1
# 4         0.0                    0      1

# %%
df.shape
# Out:
# (72274, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72274 entries, 0 to 72273
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           72274 non-null  int64
#  1   is_tv_subscriber             72274 non-null  int64
#  2   is_movie_package_subscriber  72274 non-null  int64
#  3   subscription_age             72274 non-null  float64
#  4   bill_avg                     72274 non-null  int64
#  5   reamining_contract           50702 non-null  float64
#  6   service_failure_count        72274 non-null  int64
#  7   download_avg                 71893 non-null  float64
#  8   upload_avg                   71893 non-null  float64
#  9   download_over_limit          72274 non-null  int64
#  10  churn                        72274 non-null  int64
# dtypes: float64(4), int64(7)
# memory usage: 6.1 MB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['id'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# <h3>EDA</h3>

# %% [markdown]
# <h4>Univariate Analysis</h4>

# %%
df.describe().T
# Out:
#                                count           mean            std    min  \
# id                           72274.0  846318.243462  489102.168744  15.00
# is_tv_subscriber             72274.0       0.815259       0.388090   0.00
# is_movie_package_subscriber  72274.0       0.334629       0.471864   0.00
# subscription_age             72274.0       2.450051       2.034990  -0.02
# bill_avg                     72274.0      18.942483      13.215386   0.00
# reamining_contract           50702.0       0.716039       0.697102   0.00
# service_failure_count        72274.0       0.274234       0.816621   0.00
# download_avg                 71893.0      43.689911      63.405963   0.00
# upload_avg                   71893.0       4.192076       9.818896   0.00
# download_over_limit          72274.0       0.207613       0.997123   0.00
# churn                        72274.0       0.554141       0.497064   0.00
#
#                                    25%        50%         75%         max
# id                           422216.50  847784.00  1269562.00  1689744.00
# is_tv_subscriber                  1.00       1.00        1.00        1.00
# is_movie_package_subscriber       0.00       0.00        1.00        1.00
# subscription_age                  0.93       1.98        3.30       12.80
# bill_avg                         13.00      19.00       22.00      406.00
# reamining_contract                0.00       0.57        1.31        2.92
# service_failure_count             0.00       0.00        0.00       19.00
# download_avg                      6.70      27.80       60.50     4415.20
# upload_avg                        0.50       2.10        4.80      453.30
# download_over_limit               0.00       0.00        0.00        7.00
# churn                             0.00       1.00        1.00        1.00

# %%
num = list(df.describe().columns)
plt.figure(figsize=(15, 20))
for i in range(0, len(num)):
    plt.subplot(7, 2, i+1)
    sns.histplot(x=df[num[i]], color='cornflowerblue')
    plt.xlabel(num[i])
    plt.tight_layout()

# %%
num = list(df.describe().columns)
plt.figure(figsize=(15,10))
for i in range(0, len(num)):
    plt.subplot(2, 7, i+1)
    sns.boxplot(y=df[num[i]], color='cornflowerblue', orient='v')
    plt.tight_layout()

# %% [markdown]
# <h3>Target Analysis</h3>

# %%
num = list(df.describe().columns)
plt.figure(figsize=(20,10))
for i in range(0, len(num)):
    plt.subplot(2, 7, i+1)
    sns.boxplot(y=df[num[i]], orient='v', x=df['churn'], palette="Set2")
    plt.xticks(rotation=-45, ha='left')
    plt.tight_layout()

# %%
num = list(df.describe().columns)
plt.figure(figsize=(15, 20))
for i in range(0, len(num)):
    plt.subplot(7, 2, i+1)
    sns.kdeplot(x=df[num[i]], palette="Set2", hue=df_raw['churn'])
    plt.xlabel(num[i])
    plt.tight_layout()
# Out:
# C:\Users\Muarrikh Yazka\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Muarrikh Yazka\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(15, 15))
sns.pairplot(df, diag_kind='kde', hue='churn')

# %%
plt.figure(figsize=(15, 15))
sns.heatmap(df.corr(), cmap="YlGnBu", annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3>Check Missing Value</h3>

# %%
## Check Missing Value
def check_missing_value(df): 
    total = df.isnull().sum().sort_values(ascending=False)
    percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
    missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
    missing_data = missing_data.loc[missing_data['Percent']>0]
    if missing_data.shape[0]!=0:
        return missing_data
    else:
        print('Tidak ada missing value!!!')
        
check_missing_value(df)
# Out:
#                     Total   Percent
# reamining_contract  21572  0.298475
# download_avg          381  0.005272
# upload_avg            381  0.005272

# %%
df = df.fillna(0)

# %% [markdown]
# <h3>Modelling</h3>

# %%
df_final = df.drop('id', axis=1).copy()
y = df_final.loc[:,'churn']
x = df_final.loc[:, df_final.columns!='churn']

# %%
## split train and test
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size= 0.2, random_state=42, stratify=y)
xtrain.shape, xtest.shape, ytrain.shape, ytest.shape
# Out:
# ((57819, 9), (14455, 9), (57819,), (14455,))

# %%
## standardizing
sc = StandardScaler()
xtrain_sc = sc.fit_transform(xtrain)
xtest_sc = sc.transform(xtest)

# %%
## check whether need oversampling or undersampling
counter = Counter(ytrain)
print(counter)
# Out:
# Counter({1: 32040, 0: 25779})

# %%
# %%time
logreg = LogisticRegression(random_state=42)
knn = KNeighborsClassifier()
dt = DecisionTreeClassifier(random_state=42)
rf = RandomForestClassifier(random_state=42)
xg = XGBClassifier(use_label_encoder=False)
cb = CatBoostClassifier(random_state=42, silent=True)

model = [logreg, knn, dt, rf, xg, cb]
me_sum = pd.DataFrame({'model':[],'accuracytrain':[],'accuracytest':[],'precision':[],'recall':[],'rocauc':[]})

for i in model:
    i.fit(xtrain_sc, ytrain)
    ytrainpredict = i.predict(xtrain_sc)
    ytestpredict = i.predict(xtest_sc)
    accuracytrain = round(accuracy_score(ytrain, ytrainpredict),3)
    accuracytest = round(accuracy_score(ytest, ytestpredict),3)
    precision = round(precision_score(ytest, ytestpredict),3)
    recall = round(recall_score(ytest, ytestpredict),3)
    rocauc = round(roc_auc_score(ytest, ytestpredict),3)
    name = f'{i}'.split('(')[0]
    me_sum = me_sum.append({'model':name, 
                            'accuracytrain':accuracytrain,
                            'accuracytest':accuracytest,
                            'precision':precision,
                            'recall':recall,
                            'rocauc':rocauc
                           }, ignore_index=True)
    print(name)
    print(classification_report(ytest, ytestpredict))
me_sum
# Out:
# <timed exec>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# LogisticRegression
#               precision    recall  f1-score   support
#
#            0       0.89      0.82      0.85      6445
#            1       0.86      0.91      0.89      8010
#
#     accuracy                           0.87     14455
#    macro avg       0.87      0.87      0.87     14455
# weighted avg       0.87      0.87      0.87     14455
# <timed exec>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# KNeighborsClassifier
#               precision    recall  f1-score   support
#
#            0       0.89      0.90      0.90      6445
#            1       0.92      0.91      0.91      8010
#
#     accuracy                           0.91     14455
#    macro avg       0.90      0.91      0.91     14455
# weighted avg       0.91      0.91      0.91     14455
# <timed exec>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# DecisionTreeClassifier
#               precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89      6445
#            1       0.91      0.91      0.91      8010
#
#     accuracy                           0.90     14455
#    macro avg       0.90      0.90      0.90     14455
# weighted avg       0.90      0.90      0.90     14455
# <timed exec>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# RandomForestClassifier
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93      6445
#            1       0.95      0.94      0.94      8010
#
#     accuracy                           0.94     14455
#    macro avg       0.94      0.94      0.94     14455
# weighted avg       0.94      0.94      0.94     14455
#
# [20:17:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# <timed exec>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# XGBClassifier
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93      6445
#            1       0.95      0.94      0.95      8010
#
#     accuracy                           0.94     14455
#    macro avg       0.94      0.94      0.94     14455
# weighted avg       0.94      0.94      0.94     14455
#
# <catboost.core.CatBoostClassifier object at 0x00000181AD729520>
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.93      6445
#            1       0.95      0.94      0.95      8010
#
#     accuracy                           0.94     14455
#    macro avg       0.94      0.94      0.94     14455
# weighted avg       0.94      0.94      0.94     14455
#
# Wall time: 22.6 s
# <timed exec>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#                                                model  accuracytrain  \
# 0                                 LogisticRegression          0.872
# 1                               KNeighborsClassifier          0.926
# 2                             DecisionTreeClassifier          1.000
# 3                             RandomForestClassifier          1.000
# 4                                      XGBClassifier          0.954
# 5  <catboost.core.CatBoostClassifier object at 0x...          0.950
#
#    accuracytest  precision  recall  rocauc
# 0         0.872      0.862   0.915   0.866
# 1         0.906      0.922   0.908   0.906
# 2         0.903      0.915   0.909   0.902
# 3         0.940      0.954   0.936   0.940
# 4         0.940      0.954   0.938   0.941
# 5         0.941      0.954   0.940   0.942

# %% [markdown]
# <h3>Hyperparameter Tuning</h3>

# %%
def objective(trial):
    train_x, valid_x, train_y, valid_y = train_test_split(x, y, test_size=0.3)

    param = {
        "objective": trial.suggest_categorical("objective", ["Logloss", "CrossEntropy"]),
        "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.01, 0.1),
        "depth": trial.suggest_int("depth", 1, 12),
        "boosting_type": trial.suggest_categorical("boosting_type", ["Ordered", "Plain"]),
        "bootstrap_type": trial.suggest_categorical(
            "bootstrap_type", ["Bayesian", "Bernoulli", "MVS"]
        ),
        "used_ram_limit": "3gb",
    }

    if param["bootstrap_type"] == "Bayesian":
        param["bagging_temperature"] = trial.suggest_float("bagging_temperature", 0, 10)
    elif param["bootstrap_type"] == "Bernoulli":
        param["subsample"] = trial.suggest_float("subsample", 0.1, 1)

